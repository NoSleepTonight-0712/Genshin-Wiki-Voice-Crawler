# %%
import requests
from bs4 import BeautifulSoup
from utils.global_variables import BASE_URL
from urllib.parse import urljoin

# %%
def getVoiceOverPageByIndexPage(url):
    content = requests.get(url).content
    b = BeautifulSoup(content)
    return [urljoin(BASE_URL, i.get('href')) for i in b.find_all('a', class_='category-page__member-link') if ('Category' not in i.get('href')) and len(i.get('href').split('/')) == 4]

def getAllVoiceOverPage():
    result = getVoiceOverPageByIndexPage('https://genshin-impact.fandom.com/wiki/Category:Character_Voice-Overs')
    result.extend(getVoiceOverPageByIndexPage('https://genshin-impact.fandom.com/wiki/Category:Character_Voice-Overs?from=Nilou+Voice-Overs'))
    return result

def getCharacterVoicesOnPage(character_page_url):
    b = BeautifulSoup(requests.get(character_page_url).content, features='lxml')
    character_name = b.find('h1').text.strip().split('/')[0]
    table = b.find('span', id='Story').parent.find_next('table')

    print(f'crawling {character_name}')

    if character_name != 'Traveler':
        result = []
        for td in table.find_all('td'):
            link = td.find('a').get('href')
            text = td.find('span', lang='en').text
            filename = [i for i in link.split('/') if i.endswith('.ogg')][0]
            result.append((text, link, filename))

        return character_name, character_page_url, result
    else:
        # Traveler ignore. Too long.
        pass

# %%
url = 'https://genshin-impact.fandom.com/wiki/Venti/Voice-Overs'

# %%
getCharacterVoicesOnPage(url)
# Out:
# crawling Venti
# ('Venti',
#  'https://genshin-impact.fandom.com/wiki/Venti/Voice-Overs',
#  [("*Yawn* That was a refreshing sleep. Ah, Traveler, we meet again! What? You don't remember me? Ahaha, well, allow me to join you on your quest once again. I must see to it that the bards of the world tell the Traveler's tales!",
#    'https://static.wikia.nocookie.net/gensin-impact/images/a/ad/VO_Venti_Hello.ogg/revision/latest?cb=20210113121129',
#    'VO_Venti_Hello.ogg'),
#   ("Sure, I'll play you another tune, but it'll cost you an apple.",
#    'https://static.wikia.nocookie.net/gensin-impact/images/7/73/VO_Venti_Chat_-_Playing_the_Lyre.ogg/revision/latest?cb=20210113121113',
#    'VO_Venti_Chat_-_Playing_the_Lyre.ogg'),
#   ('Right now I wish I was sat at the top of a tree, looking out over a meadow, cider in hand... *sigh*',
#    'https://static.wikia.nocookie.net/gensin-impact/images/e/ee/VO_Venti_Chat_-_Apple_Cider.ogg/revision/latest?cb=20210113121111',
#    'VO_Venti_Chat_-_Apple_Cider.ogg'),
#   ("Come on Traveler, let's go! The world is full of lost ballads just waiting to be rediscovered.",
#    'https://static.wikia.nocookie.net/gensin-impact/images/1/15/VO_Venti_Chat_-_Ballads.ogg/revision/latest?cb=20210113121112',
#    'VO_Venti_Chat_-_Ballads.ogg'),
#   ("Let's go jumping in puddles and see who can make the biggest splash!",
#    'https://static.wikia.nocookie.net/gensin-impact/images/a/ad/VO_Venti_When_It_Rains.ogg/revision/latest?cb=20210113121044',
#    'VO_Venti_When_It_Rains.ogg'),
#   ("It's stopped raining already? A shame, I wanted to play some more.",
#    'https://static.wikia.nocookie.net/gensin-impact/images/c/c0/VO_Venti_After_the_Rain.ogg/revision/latest?cb=20210113121108',
#    'VO_Venti_After_the_Rain.ogg'),
#   ("Let's wait till the snow gets heavier and have a snowball fight!",
#    'https://static.wikia.nocookie.net/gensin-impact/images/2/26/VO_Venti_When_It_Snows.ogg/revision/latest?cb=20210113121045',
#    'VO_Venti_When_It_Snows.ogg'),
#   ("The wind has returned! Quick, let's go gliding!",
#    'https://static.wikia.nocookie.net/gensin-impact/images/7/75/VO_Venti_When_the_Wind_Is_Blowing.ogg/revision/latest?cb=20210113121046',
#    'VO_Venti_When_the_Wind_Is_Blowing.ogg'),
#   ("Morning! What's in store for today?",
#    'https://static.wikia.nocookie.net/gensin-impact/images/b/bc/VO_Venti_Good_Morning.ogg/revision/latest?cb=20210113121127',
#    'VO_Venti_Good_Morning.ogg'),
#   ("My tummy is rumbling, but I can't get caught pilfering food from the Dawn Winery again... Oh, it's you! Where are you heading? May I join?",
#    'https://static.wikia.nocookie.net/gensin-impact/images/a/a3/VO_Venti_Good_Afternoon.ogg/revision/latest?cb=20210113121124',
#    'VO_Venti_Good_Afternoon.ogg'),
#   ("I'm still not sleepy, fancy an evening stroll?",
#    'https://static.wikia.nocookie.net/gensin-impact/images/b/b4/VO_Venti_Good_Evening.ogg/revision/latest?cb=20210113121126',
#    'VO_Venti_Good_Evening.ogg'),
#   ('Off to the land of nod? Haha, Farewell my friend!',
#    'https://static.wikia.nocookie.net/gensin-impact/images/f/fb/VO_Venti_Good_Night.ogg/revision/latest?cb=20210113121128',
#    'VO_Venti_Good_Night.ogg'),
#   ("Practice? Me? There's no need - I already know every song in Teyvat!",
#    'https://static.wikia.nocookie.net/gensin-impact/images/4/45/VO_Venti_About_Venti.ogg/revision/latest?cb=20210113121107',
#    'VO_Venti_About_Venti.ogg'),
#   ("I have decided to write a song about you! What are you giving me that look for? Can't afford it? Don't be preposterous, the price for you, my friend, is precisely zero Mora! Although... one thing you could do is tell me a few more of your stories!",
#    'https://static.wikia.nocookie.net/gensin-impact/images/e/e0/VO_Venti_About_Us_-_New_Songs.ogg/revision/latest?cb=20210113121104',
#    'VO_Venti_About_Us_-_New_Songs.ogg'),
#   ('Media:VO Venti About Us - Heroes (A).ogg Media:VO Venti About Us - Heroes (B).ogg Haha, once the (heroheroText for Aether/heroineheroineText for Lumine) in the song has actually rescued the (princessprincessText for Aether/princeprinceText for Lumine), I will ensure this song spreads to every corner of the continent!',
#    'https://static.wikia.nocookie.net/gensin-impact/images/1/1e/VO_Venti_About_Us_-_Heroes_%28A%29.ogg/revision/latest?cb=20210113121102',
#    'VO_Venti_About_Us_-_Heroes_%28A%29.ogg'),
#   ("An evening breeze really sets the mood for becoming my disciple, don't you think? We can do it right now, you just need to make me a small offering...",
#    'https://static.wikia.nocookie.net/gensin-impact/images/b/b1/VO_Venti_About_Us_-_Apostles.ogg/revision/latest?cb=20210113121100',
#    'VO_Venti_About_Us_-_Apostles.ogg'),
#   ("What's that? You think I should try harder to be a good Anemo Archon? Well you could be a better devotee too... you could be more pious, more passionate, or... um...",
#    'https://static.wikia.nocookie.net/gensin-impact/images/f/fb/VO_Venti_About_Us_-_Requests.ogg/revision/latest?cb=20210113121106',
#    'VO_Venti_About_Us_-_Requests.ogg'),
#   ('Hmm? You want to know about my Vision? Oh, go on then, take a look for yourself. I can make you a matching one if you like! Hehehe.',
#    'https://static.wikia.nocookie.net/gensin-impact/images/e/e5/VO_Venti_About_the_Vision.ogg/revision/latest?cb=20210113121059',
#    'VO_Venti_About_the_Vision.ogg'),
#   ('Olah! Haha, that\'s how the Hilichurls say "hello". Why, I learned it to aid with my songwriting, of course! Vast knowledge makes for a richer composition... That said, I haven\'t actually written any songs in Hilichurlian so far...',
#    'https://static.wikia.nocookie.net/gensin-impact/images/0/0a/VO_Venti_Something_to_Share.ogg/revision/latest?cb=20210113121040',
#    'VO_Venti_Something_to_Share.ogg'),
#   ("Traveler, have you ever seen a cecilia? It's a magnificent white wildflower that only grows on the most remote mountains and clifftops. To me, at least, it is the most beautiful flower in all of Teyvat.",
#    'https://static.wikia.nocookie.net/gensin-impact/images/a/ac/VO_Venti_Interesting_Things.ogg/revision/latest?cb=20210113121131',
#    'VO_Venti_Interesting_Things.ogg'),
#   ("Acting Grand Master Jean... Well, what do you think of her? Yes, I couldn't agree more: conscientious, courageous... kind and considerate too. Reminds me of another good friend...",
#    'https://static.wikia.nocookie.net/gensin-impact/images/6/6a/VO_Venti_About_Jean.ogg/revision/latest?cb=20210113121054',
#    'VO_Venti_About_Jean.ogg'),
#   ("I'm not surprised you want to befriend Master Diluc, just think of all vintage wine he must have stored away... Mwuhahaha... Huh? He doesn't let you sample it? Not even the slightest drop? Huh... Well, I guess you can still appreciate the aroma. That's still better than no wine at all, right? No?",
#    'https://static.wikia.nocookie.net/gensin-impact/images/9/97/VO_Venti_About_Diluc.ogg/revision/latest?cb=20210113121051',
#    'VO_Venti_About_Diluc.ogg'),
#   ("The darling Deaconess with the sweet singing voice — do you know her? You do? Idol, huh? Meet and greets? Concerts? Wow... That's the power of music for you...",
#    'https://static.wikia.nocookie.net/gensin-impact/images/7/7d/VO_Venti_About_Barbara.ogg/revision/latest?cb=20210113121049',
#    'VO_Venti_About_Barbara.ogg'),
#   ('Ah yes, the white-haired fellow from Wolvendom? Raised by wolves? Really? ... No wonder his scent is so familiar...',
#    'https://static.wikia.nocookie.net/gensin-impact/images/d/db/VO_Venti_About_Razor.ogg/revision/latest?cb=20211013143627',
#    'VO_Venti_About_Razor.ogg'),
#   ("Oh, that astrologer? How should I put it? Fortune telling and my singing are the same. Both lead to you being so poor you can't even cough up the money for a drink! ...You think that astrology is a cultural tradition, so at least still has some value? Hmph, so rude. In that case, so too is singing, so it still has its value too!",
#    'https://static.wikia.nocookie.net/gensin-impact/images/f/f2/VO_Venti_About_Mona.ogg/revision/latest?cb=20210113121056',
#    'VO_Venti_About_Mona.ogg'),
#   ("There's a special drink known far and wide at Cat's Tail. But it ah... ahh... ACHOO! *sniffs* How about you go and fetch one for me? I'll be truly thankful, I promise.",
#    'https://static.wikia.nocookie.net/gensin-impact/images/e/e0/VO_Venti_About_Diona.ogg/revision/latest?cb=20210113121052',
#    'VO_Venti_About_Diona.ogg'),
#   ("How do you explain white chalk in black soil, or the earth's dense crust amidst the emptiness of space? Same reason the purest soil gave birth to human life... It's an ancient power with unmistakable properties. Trying to harness it is dangerous indeed, I can't imagine what would happen if someone lost control of it in the city... Ah, never mind! What goes on within Mondstadt's walls is up to Mondstadt's people to deal with!",
#    'https://static.wikia.nocookie.net/gensin-impact/images/8/83/VO_Venti_About_Albedo.ogg/revision/latest?cb=20210113121048',
#    'VO_Venti_About_Albedo.ogg'),
#   ("Have you seen that gentleman around? Huh? He's just a normal man by the name of Zhongli now? That must be quite the change for that old block-head. Come with me to see him, will you? I have a vintage I dug up from Windrise that I can take as a condolence gift. Oh, ahh... did he still seem strong when you saw him? How strong? Am I likely to get blown away?",
#    'https://static.wikia.nocookie.net/gensin-impact/images/1/13/VO_Venti_About_Morax.ogg/revision/latest?cb=20210113121533',
#    'VO_Venti_About_Morax.ogg'),
#   ("Eula has good taste when it comes to beverages of the alcoholic variety. Come summer or winter, she always likes them ice-cold. That's rare among Mondstadters these days! She and I would make great drinking buddies. Huh? My songs about the Lawrence Clan... She's heard them already? Eh, no harm done. Maybe she and I can do a duet sometime!",
#    'https://static.wikia.nocookie.net/gensin-impact/images/6/66/VO_Venti_About_Eula.ogg/revision/latest?cb=20210512234843',
#    'VO_Venti_About_Eula.ogg'),
#   ('So, I hear you defeated the mighty Raiden Shogun? Ah, I recall the days when she was a kagemusha, seeking to perfect her martial prowess. Hehe, she now no doubt employs a wide range of reasoning to get you to train with her. Oh but yes, come close and I shall let you in on her weakness — desserts!',
#    'https://static.wikia.nocookie.net/gensin-impact/images/3/3a/VO_Venti_About_Baal.ogg/revision/latest?cb=20210905062714',
#    'VO_Venti_About_Baal.ogg'),
#   ('The first thing you think of when you hear "Dendro Archon" is her power over dreams. Her dreams are akin to my ballads: full of emotion and imagination. It goes without saying that we get along really well.',
#    'https://static.wikia.nocookie.net/gensin-impact/images/3/36/VO_Venti_About_Buer.ogg/revision/latest?cb=20221114150549',
#    'VO_Venti_About_Buer.ogg'),
#   ('Perfect timing, Traveler! I was about to ask you — what is your greatest wish?',
#    'https://static.wikia.nocookie.net/gensin-impact/images/e/e5/VO_Venti_More_About_Venti_-_01.ogg/revision/latest?cb=20210113121134',
#    'VO_Venti_More_About_Venti_-_01.ogg'),
#   ("There's never a dull moment traveling with you! The only minor inconvenience is that pesky little pixie thing that follows you everywhere... she never stops eating, I can't begin to imagine how much you spend on food!",
#    'https://static.wikia.nocookie.net/gensin-impact/images/8/88/VO_Venti_More_About_Venti_-_02.ogg/revision/latest?cb=20210113121135',
#    'VO_Venti_More_About_Venti_-_02.ogg'),
#   ('The Pyro Archon is a wayward, warmongering wretch, and the Geo Archon is a brutish blundering buffoon! How do I know? Because, this is written in the epic poems of days gone by!',
#    'https://static.wikia.nocookie.net/gensin-impact/images/c/c3/VO_Venti_More_About_Venti_-_03.ogg/revision/latest?cb=20210113121136',
#    'VO_Venti_More_About_Venti_-_03.ogg'),
#   ("Celestia... I'm not sure even I could fly that far. In any case, the water there tastes foul and the fruit is bland. You know what that means? No cider! Haha, in that case, I wouldn't go there even if I was invited.",
#    'https://static.wikia.nocookie.net/gensin-impact/images/e/eb/VO_Venti_More_About_Venti_-_04.ogg/revision/latest?cb=20210113121138',
#    'VO_Venti_More_About_Venti_-_04.ogg'),
#   ('My greatest wish? It has always been to roam free and experience the whole world. Now I would add that wherever I go, it simply must be with you! Each day with you is an adventure, and where adventurers go, storytellers must follow!',
#    'https://static.wikia.nocookie.net/gensin-impact/images/5/54/VO_Venti_More_About_Venti_-_05.ogg/revision/latest?cb=20210113121038',
#    'VO_Venti_More_About_Venti_-_05.ogg'),
#   ('I like to drink! And I like the wind! If only there were such a thing as wind-brewed cider...',
#    'https://static.wikia.nocookie.net/gensin-impact/images/c/c3/VO_Venti_Hobbies.ogg/revision/latest?cb=20210113121041',
#    'VO_Venti_Hobbies.ogg'),
#   ("I'm actually highly allergic to cats, I start sneezing as soon as they enter the vicinity, and... Aaah... Aa-choo! Ugh, apparently I can't even THINK about cats without sneezing. Do you think there is a cure for this monstrous affliction?",
#    'https://static.wikia.nocookie.net/gensin-impact/images/0/00/VO_Venti_Troubles.ogg/revision/latest?cb=20210113121042',
#    'VO_Venti_Troubles.ogg'),
#   ('Here, have an apple. I just picked it. Look how ripe and juicy it is... *munching*... Truly the fruit of the gods.',
#    'https://static.wikia.nocookie.net/gensin-impact/images/7/7d/VO_Venti_Favorite_Food.ogg/revision/latest?cb=20210113121115',
#    'VO_Venti_Favorite_Food.ogg'),
#   ("What's that tasty morsel you've got there... Eew! A melted cheese pancake! A smelly, sticky, slimy disgusting mess!",
#    'https://static.wikia.nocookie.net/gensin-impact/images/1/14/VO_Venti_Least_Favorite_Food.ogg/revision/latest?cb=20210113121132',
#    'VO_Venti_Least_Favorite_Food.ogg'),
#   ('Ahh, quite delightful! So... could I get the same thing again tomorrow? ...And maybe the day after that?',
#    'https://static.wikia.nocookie.net/gensin-impact/images/6/62/VO_Venti_Receiving_a_Gift_-_01.ogg/revision/latest?cb=20220514160137',
#    'VO_Venti_Receiving_a_Gift_-_01.ogg'),
#   ("Oof, I'm so full... I'll have to pass on the post-meal fruits this time...",
#    'https://static.wikia.nocookie.net/gensin-impact/images/c/cc/VO_Venti_Receiving_a_Gift_-_02.ogg/revision/latest?cb=20220514160139',
#    'VO_Venti_Receiving_a_Gift_-_02.ogg'),
#   ("I can't believe it, but I don't think I can stomach this... Oh boy... What a predicament.",
#    'https://static.wikia.nocookie.net/gensin-impact/images/8/8d/VO_Venti_Receiving_a_Gift_-_03.ogg/revision/latest?cb=20220514160135',
#    'VO_Venti_Receiving_a_Gift_-_03.ogg'),
#   ("Someone once told me you're supposed to eat a cake on your birthday... Tada! Here's your birthday cake — it's apple flavored! And here's a spoon. The cake didn't rise properly in the oven, that's why it looks more akin to an apple pie... Ugh, baking is really quite complicated!",
#    'https://static.wikia.nocookie.net/gensin-impact/images/e/e4/VO_Venti_Birthday.ogg/revision/latest?cb=20210113121110',
#    'VO_Venti_Birthday.ogg'),
#   ('Woah! What was that?',
#    'https://static.wikia.nocookie.net/gensin-impact/images/b/be/VO_Venti_Feelings_About_Ascension_-_01.ogg/revision/latest?cb=20210113121120',
#    'VO_Venti_Feelings_About_Ascension_-_01.ogg'),
#   ('Good work. Shall we repose for a moment, with a tune? Shall it be a capriccio, or a serenade?',
#    'https://static.wikia.nocookie.net/gensin-impact/images/a/a6/VO_Venti_Feelings_About_Ascension_-_02.ogg/revision/latest?cb=20210113121116',
#    'VO_Venti_Feelings_About_Ascension_-_02.ogg'),
#   ('Come, sit with me. I\'ve written a new poem. I call it "Wind of the Traveler."',
#    'https://static.wikia.nocookie.net/gensin-impact/images/9/95/VO_Venti_Feelings_About_Ascension_-_03.ogg/revision/latest?cb=20210113121117',
#    'VO_Venti_Feelings_About_Ascension_-_03.ogg'),
#   ("Hmm... Though I've long since viewed this scenery a great many times, there is something different about seeing it again with you. Surely you're not still concealing some other wondrous abilities? Hmm, even if you were, it would simply further prove that my intuition is correct.",
#    'https://static.wikia.nocookie.net/gensin-impact/images/2/21/VO_Venti_Feelings_About_Ascension_-_04.ogg/revision/latest?cb=20210113121119',
#    'VO_Venti_Feelings_About_Ascension_-_04.ogg')])
